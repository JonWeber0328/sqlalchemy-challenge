# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Reflect Tables into SQLALchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# Identify the average temperature for June
avg_J = June["tobs"].mean()
print(f"The average temperature for June is {avg_J}.")

# %%
# Identify the average temperature for December
avg_D = December["tobs"].mean()
print(f"The average temperature for December is {avg_D}.")

# %%
# Create collections of temperature data
J_temp = June["tobs"]

D_temp = December["tobs"]
print(f"{J_temp},{D_temp}")

# %%
# Run paired t-test
t_stat = stats.ttest_ind(J_temp, D_temp, equal_var=False)
t_stat

# %% [markdown]
# ##  Analysis

# %% [markdown]
# #### Use the t-test to determine whether the difference in the means, if any, is statistically significant. Will you use a paired t-test, or an unpaired t-test? Why?

# %% [markdown]
# <font color='blue'>Using scipy.stats.ttest_ind we are conducting an unpaired t-test using data from two different or unrelated groups, June temperature data and December temperature data. We are not using a paired t-test because our two data sets are independent and different sizes. Additionally, equal_var was set to false because we are assuming unequal population variance.</font>
#
# <font color='blue'>Our t-test pvalue was less than 5% and we are rejecting the null hypothesis that the two independent samples have the same expected population mean.</font>
